# %% [markdown]
# <a href="https://colab.research.google.com/github/HY-BME/bme_test_files/blob/%EB%B0%94%EC%9D%B4%EC%98%A4%EA%B3%B5%ED%95%99%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4%EA%B8%B0%EC%88%A0/ML_0331.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#모델 오차 파악
#RMSE : Root Mean Squared Error : 제곱(음수 상쇄 및 큰 오차에 패널티 부여)의 평균에 루트(원래 단위로 복귀)를 씌움
#https://velog.io/@hyesoup/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D-%ED%9A%8C%EA%B7%80-%EB%AA%A8%EB%8D%B8%EC%9D%98-%EC%84%B1%EB%8A%A5-%ED%8F%89%EA%B0%80-%EC%A7%80%ED%91%9C-MAE-MSE-RMSE-R-squred

# y = Wx + b
# W : 가중치. 계수
# x : 독립변수
# y : 종속변수
# b : 편향.Bias.Offset (y절편. x=0일때 값)

#상관관계 : 인과관계를 설명하지는 않는다 - 원인/결과는 도메인지식으로 파악 (상관관계는 단순 변수들의 관련성만을 나타냄)

#오차함수 : loss(w, b) //가중치, 편향 손실함수
#과소적합 : 모델이 너무 단순하여 데이터에 내제된 복잡한 양상을 포착하지 못하는 현상

#cross-validation : 학습 데이터 범위를 벗어나는 외부 데이터를 활용하여 검증 ex) 10 fold cross validation. 전북대병원 의료 영상 데이터로 학습한 모델을 다른 병원 의료영상 데이터를 테스트 셋으로하여 검증
