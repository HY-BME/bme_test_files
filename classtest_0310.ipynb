# %% [markdown]
# <a href="https://colab.research.google.com/github/HY-BME/bme_test_files/blob/%EB%B0%94%EC%9D%B4%EC%98%A4%EA%B3%B5%ED%95%99%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4%EA%B8%B0%EC%88%A0/classtest_0310.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (1) 데이터 로드
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

iris = load_iris()
X = iris.data
y = iris.target

# (2) 데이터셋 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# (3) 데이터 정규화
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# (1) 모델 생성
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

# (2) 예측
y_pred_knn = knn.predict(X_test)

# (3) 정확도 평가
accuracy_knn = accuracy_score(y_test, y_pred_knn)
print(f'KNN 정확도: {accuracy_knn}')

# (4) 학습데이터에 대한 정확도 평가
y_pred_knn_train = knn.predict(X_train)

accuracy_knn_train = accuracy_score(y_train, y_pred_knn_train)
print(f'KNN 정확도(학습): {accuracy_knn_train}')
# Out:
# KNN 정확도: 1.0
# KNN 정확도(학습): 0.9428571428571428

# %%
from sklearn.tree import DecisionTreeClassifier

# (1) 모델 생성
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)

# (2) 예측
y_pred_dt = dt.predict(X_test)

# (3) 정확도 평가
accuracy_dt = accuracy_score(y_test, y_pred_dt)
print(f'의사결정나무 정확도: {accuracy_dt}')
# Out:
# 의사결정나무 정확도: 1.0
